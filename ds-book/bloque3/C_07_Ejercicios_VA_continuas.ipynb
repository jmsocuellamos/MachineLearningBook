# %% [markdown]
# # <font color="steelblue">210. Ejercicios variables aleatorias continuas</font>
#
# **Material desarrollado por los [equipos de trabajo de IA4LEGOS](https://ia4legos.umh.es/)**
#
#
# **Fecha última edición**: 10/05/2025
#
# **Licencia**: <small><a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br /></small>
#
# No olvides hacer una copia si deseas utilizarlo. Al usar estos contenidos, aceptas nuestros términos de uso y nuestra política de privacidad.

# %% [markdown]
# ## <font color='steelblue'>Introducción</font>
#
# **Descripción:** Colección de ejercicios sobre variables aleatorias continuas.

# %%
# Cargamos módulos de análisis numérico
import numpy as np          # importamos numpy como np
import pandas as pd         # importamos pandas como pd
import math                 # importamos módulo para cáculos matemáticos

# Cargamos módulos de análisis gráficos
from plotnine import *      # importamos módulo para gráficos con ggplot
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %config InlineBackend.figure_format = 'retina'

from scipy import stats

# %% [markdown]
# ### **EJ001.**
#
# Se sabe que el tiempo que tarda el autobús de línea en hacer el recorrido Elche-Playa de arenales está entre 25 y 45 minutos. Asumiendo una distribución uniforme responde a las cuestiones siguientes.
#
# * Tengo que avisar a mi amigo de que me recoja, y lo avisaré antes de salir. ¿Cuánto tiempo le digo que voy a tardar?
# * ¿Qué probabilidad hay de que tarde más de media hora en llegar?

# %% [markdown]
# ### **EJ002.**
#
# Se ha comprobado que el tiempo de vida de cierto tipo de marcapasos sigue una distribución exponencial con media 16 años.
#
# * ¿Cuál es la probabilidad de que a una persona a la que se le ha implantado este marcapasos se le deba reimplantar otro antes de 20 años?
# * Si el marcapasos lleva funcionando correctamente 5 años en un paciente, ¿cuál es la probabilidad de que haya que cambiarlo antes de 25 años desde que se implantó?

# %% [markdown]
# ### **EJ003**.
#
# Un motor eléctrico tiene una vida media de 6 años y se modeliza con una distribución exponencial. ¿Cuál debe ser el tiempo de garantía que debe tener el motor si se desea que a lo sumo el 15% de los motores fallen antes de que expire su garantía?

# %% [markdown]
# ### **EJ004**.
#
# El contenido de las botellas de jugo de naranja llenadas por una máquina automática tiene una distribución aproximadamente normal con media 330 ml y desviación típica de 2 ml. Encontrar la probabilidad de que:
#
# * Una botella contenga menos de 325 ml de jugo de naranja.
# * Una botella contenga al menos 320 ml de jugo de naranja

# %% [markdown]
# ### **EJ005.**
#
# El contenido de una bandeja de jamón serrano de alta calidad contiene 140 gramos. Para clasificarlo como de alta gama el contenido en grasa de dicha bandeja debe tener en promedio un contenido de 12.34 gramos con una desviación admisible de 0.8 gramos. Se está interesado en conocer:
#
# * ¿Qué porcentaje de bandejas tiene un contenido de grasa entre 10.2 gramos y 12.5 gramos?.
# * ¿Qué porcentaje de bandejas tienen más de 14 gramos de grasa?

# %% [markdown]
# ### **EJ006.**
#
# En el estudio Framingham acerca de factores que afectan las enfermedades cardíacas se hizo un seguimiento por un período de 16 años a una gran cantidad de hombres sanos. Se encontró que inicialmente la distribución de los niveles de colesterol de los hombres era Normal con media 224 y con desviación típica 48. A partir de los resultados de ese estudio se plantean las cuestiones siguientes:
#
# * Una persona con un colesterol menor de 200 es considerada como una con bajo riesgo de tener complicaciones cardíacas. ¿Qué porcentaje de hombres tendrán bajo riesgo?
# * Si el colesterol de la persona es mayor de 250 entonces tendrá problemas cardiacos en el futuro. ¿Qué porcentaje de hombres tendrán problemas cardiacos?
# * Los hombres que tienen el 5% más alto de colesterol serán sometidos a una dieta, para bajarle su colesterol y evitar que tenga problemas cardiacos en el futuro. ¿Cuál será el nivel de colesterol máximo permitido para no someterse a la dieta?

# %% [markdown]
# ### **EJ007.**
#
# En los estudios sobre huellas dactilares una característica muy importante es el número de crestas cuando tomamos las huellas digitales de los 10 dedos. Si asumimos que la distribución del número de crestas es normal con media 140 y desviación típica 50, encontrar la probabilidad  de que un individuo cualquiera de la población:
#
# * Tenga 200 crestas o más
# * Tenga menos de 100 crestas
# * Tenga entre 200 y 250 crestas
# * Si la población está compuesta por 10000 sujetos ¿cuántos esperamos observar con 200 crestas o más?

# %% [markdown]
# ### **EJ008.**
#
# Un empleado viaja todos los días desde las afueras de la ciudad a u oficina que esta situada en el centro. El tiempo promedio para un viaje sólo de ida es de 24 minutos, con una desviación típica de 3.8 minutos. Si se supone que la distribución de los tiempos de viaje es Normal:
#
# * ¿Cuál es la probabilidad de que un viaje tome al menos media hora?
# * Si la oficina abre a las 9:00 a.m. y él sale diario de su casa a las 8:45 a.m., ¿qué porcentaje de las veces llegará tarde al trabajo?
# * Si sale de su casa a las 8:35 a.m. y el café. se sirve en la oficina de 8:50 a.m. a 9:00 a.m., ¿cuál es la probabilidad de que no se pierda el café?
# * Calcula la duración mayor en la que se encuentra el 15% de los viajes más lentos.

# %% [markdown]
# ### **EJ009.**
#
# Una empresa paga a sus empleados un salario promedio de 15.90 euros por hora, con una desviación típica de 1.50 euros. Si los salarios se distribuyen aproximadamente de forma Normal (redondeando al céntimo más cercano), nos planteamos:
#
# * ¿Qué porcentaje de los trabajadores recibe un salario de entre 13.75 y 16.22 euros por hora?
# * ¿el 5% de los salarios más altos por hora de los empleados es mayor a qué cantidad?

# %% [markdown]
# ### **EJ010.**
#
# En el proceso de fabricación de unas piezas intervienen dos máquinas: la máquina A produce un taladro cilíndrico y la máquina B secciona las piezas con un grosor determinado. Ambos procesos son independientes. El diámetro del taladro producido por A (en mm.) es una variable Nomral con media 23 y desviación típica 0.5. El grosor producido por B (en mm.) es una variable Normal con media 11.5 desviación típica 0.4.
#
# * Calcula qué porcentaje de piezas tienen una taladro comprendido entre 20.5 y 24 mm.
# * Encuentra el porcentaje de piezas que tienen un grosor entre 10.5 y 12.7 mm.
# * Suponiendo que sólo son válidas las piezas cuyas medidas son las dadas en los apartados anteriores, calcula qué porcentaje de piezas aceptables se consiguen.

# %% [markdown]
# ### **EJ011.**
#
# Supongamos que el diámetro de las aceitunas rellenas de anchoa varía entre 15 y 17 mm. Debido a al sequía del último año, la producción de aceituna verde se ha distribuido según una normal de media 15.5 mm. y desviación típica 1.2 mm. ¿Qué porcentaje de aceitunas podría ser aprovechado para rellenar de anchoa?

# %% [markdown]
# ### **EJ012**.
#
# El peso de los toros de una ganadería se distribuyen según una distribución normal de 500 kg de media y 45 kg de desviación típica. Si la ganadería tiene 2000 toros:
#
# * ¿Cuántos pesarán más de 540 kg?
# * ¿Cuántos pesarán menos de 480 kg?
# * ¿Cuántos pesarán entre 490 y 510 kg?

# %% [markdown]
# ### **EJ013.**
#
# La duración media de un lavavajillas es de 15 años y su desviación típica 0.5. Sabiendo que la vida útil del lavavajillas se distribuye normalmente, hallar la probabilidad de que al adquirir un lavavajillas, este dure más de 15 años.

# %% [markdown]
# ### **EJ014.**
#
# La compañía aérea "Alillas" sabe que el tiempo de retraso de sus vuelos se distribuye normalmente, con un retraso medio de 10 minutos y desviación típica 5 minutos. Calcular:
#
# * Probabilidad de que un vuelo no tenga retraso.
# * Probabilidad de que el próximo vuelo llegue con no más de 10 minutos de retraso.
# * Probabilidad de que el próximo vuelo llegue con más de 20 minutos de retraso.

# %% [markdown]
# ### **EJ015**.
#
# El tiempo necesario para que una ambulancia llegue a un centro deportivo se distribuye según una variable normal de media 17 minutos y desviación típica 3 minutos.
#
# * Calcular la probabilidad de que el tiempo de llegada esté comprendido entre 13 y 21 minutos.
# * ¿Para qué valor del tiempo t, la probabilidad de que la ambulancia emplee más de t minutos en llegar es del 5%?

# %% [markdown]
# ### **EJ016.**
#
# En un gran estadio deportivo se quiere instalar focos para iluminar el campo de juego. El suministrador asegura que el tiempo de vida de los focos es, aproximadamente, normal con media 40 horas y desviación típica 4 horas.
#
# * Escogiendo un foco al azar, ¿cuál es la probabilidad de que luzca al menos 30 h?
# * Si se compran 1500 focos, ¿cuántos se puede esperar que luzcan por lo menos 30 h?
# * Si se comprueba que sólo 1400 focos lucen durante más de 30 h, ¿qué puede deducirse?

# %% [markdown]
# **EJ017.** Una normativa europea obliga a que en los envases de yogur no debe haber menos de 120 gr. La máquina dosificadora de una empresa láctea hace los envases de yogur según una distribución normal de desviación típica de 2 gr. y media 122 gr.
#
# * ¿Qué tanto por ciento de los envases de yogur de esa empresa cumplirá la normativa?
# * ¿Cuál deberá ser la media de la distribución normal con la cual la máquina dosificadora debe hacer los envases para que el 98% de la producción de yogures de la empresa cumpla la normativa?. (La desviación típica sigue siendo de 2 gr.).

# %% [markdown]
# ### **EJ018.**
#
# Una barra recta se forma conectando tres secciones A,B y C, cada una fabricada con una máquina distinta. La longitud de la sección A, en pulgadas, tiene una distribución normal con media 20 y varianza 0.04. La longitud de la sección B tiene una distribución normal con media 14 y varianza 0.01. La longitud de la sección C tiene una distribución normal con media 26 y varianza 0.04. Las tres secciones e unen de forma que se superponen 2 pulgadas en cada conexión. Si la barra se utiliza en la construcción del ala de un avión y su longitud debe estar entre 55.7 y 56.3 pulgadas ¿cuál es la probabilidad de que la barra sea utilizada?

# %% [markdown]
# **Teorema Central del Límite**

# %% [markdown]
# ### **EJ019.**
#
# Una compañía aérea sabe que el equipaje de sus pasajeros tiene como media 25 kg. con una desviación típica de 6 kg. Si uno de sus aviones transporta a 50 pasajeros, ¿cuál es la probabilidad de que la media del peso del equipaje por pasajero sea superior a 26 kg?

# %% [markdown]
# ### **EJ020.**
#
# Una empresa utiliza un máquina para llenar las botellas de un refresco. Se supone que las botellas deben contener 300ml, pero un estudio detallado demuestra que la media del contenido es de 298 ml con una desviación típica de 3 ml. ¿Cuál es la probabilidad de que la media de los contenidos de un paquete de 6 botellas tenga menos de 295ml?

# %% [markdown]
# ### **EJ021.**
#
# El benceno es una sustancia química altamente tóxica para los seres humanos. Sin embargo, se utiliza en la fabricación de medicamentos, de tintes y de recubrimientos, así como en la peletería. Las regulaciones del gobierno establecen que el contenido de benceno en el agua que resulte de cualquier proceso de producción en el que participe esta sustancia no debe exceder 7950 partes por millón (ppm). Para un proceso particular de interés, un fabricante conoce que la media del contenido de benceno es de 7960 ppm con una desviación típica de 100 ppm. Si el proceso realiza 25 repeticiones ¿Cuál es la probabilidad de que la media del contenido de benceno del experimento sobrepase el límite permitido por la regulación?

# %% [markdown]
# ### **EJ022.**
#
# Una empresa de mensajería que opera en la ciudad tarda una media de 35 minutos en llevar un paquete, con una desviación típica de 8 minutos. Supongamos que durante el día de hoy han repartido doscientos paquetes.
#
# * ¿Cuál es la probabilidad de que la media de los tiempos de entrega de hoy esté entre 30 y 35 minutos?
# * ¿Cuál es la probabilidad de que, en total, para los doscientos paquetes hayan estado más de 115 horas?

# %% [markdown]
# ### **EJ023.**
#
# En un experimento de laboratorio se mide el tiempo de una reacción química. Se ha repetido el experimento 98 veces y se obtiene que la media de los 98 experimentos es de 5 segundos con una desviación de 0,05 segundos. ¿Cuál es la probabilidad de que la media poblacional m difiera de la media muestral en menos de 0,01 segundos?

# %% [markdown]
# ### **EJ024.**
#
# Si se sabe que la dureza Rockwell de pernos de cierto tipo tiene un valor medio de 50 y desviación estándar de 1,5.
#
# * Si la distribución es normal, ¿cuál es la probabilidad de que la dureza muestral media para una muestra aleatoria de 9 pernos sea por lo menos 52?
# * ¿Cuál es la probabilidad (aproximada) de que la dureza muestral media para una muestra aleatoria de 40 pernos sea al menos 52?

# %% [markdown]
# ### **EJ025.**
#
# Se sabe que la distribución del número de defectos en un determinado rollo de tela sigue una distribución de Poisson de media 5. Para una muestra de 125 rollos se cuenta el número e defectos en cada rollo. Determinar la probabilidad de que el número promedio de defectos por rollo en la muestra sea menor que 5.5.

# %% [markdown]
# **Aproximaciones de la Normal a la Binomial y Poisson**

# %% [markdown]
# ### **EJ026.**
#
# El 2% de los tornillos fabricados por una máquina presentan defectos. Si tenemos un lote de 200 tornillos, ¿cuál es la probabilidad de que haya más de 5 defectuosos?

# %% [markdown]
# ### **EJ027.**
#
# La probabilidad de que una copa de cristal se rompa cuando la transportamos es del 1%. Si se transportan 1000 copas:
#
# * ¿cuál es el número esperado de roturas? ¿Y la desviación típica?
# * ¿Cuál es la probabilidad de que se rompan 20 copas o más?

# %% [markdown]
# ### **EJ028.**
#
# Una plantación está infectada por unos escarabajos, y se estima que hay 5000000 de estos animalillos. Se rocía la plantación con un insecticida que se espera que acabe con el 80% de los bichos.
#
# * ¿Cuál es la probabilidad de que sobrevivan 500000 escarabajos o más?
# * ¿Y la de que sobrevivan más de 300000 escarabajos?
# * ¿Y la de que sobrevivan entre 100000 y 200000 escarabajos?

# %% [markdown]
# ### **EJ029.**
#
# En una partida de disquetes para ordenador se detecta que el 20% están defectuosos. Para vender esos disquetes se ofertan 8 al precio de 5.
#
# * ¿Hasta qué punto es interesante comprar esos disquetes?.
# * Si una empresa compra 1000 disquetes, ¿cuánto debe pagar y cuántos cabe esperar que sean defectuosos?

# %% [markdown]
# ### **EJ030.**
#
# Se conoce, por estudios previos, que la proporción de reses que enfermarán después de suministrarles una determinada vacuna es del 2%. Una granja tiene 600 reses que son vacunadas.
#
# * Determina el número esperado de reses que no enfermarán.
# * Halla la probabilidad de que el número de reses que enferman sea, como máximo, 20.
# * Determina la probabilidad de que el número de reses que no enferman sea, como mínimo, 590.

# %% [markdown]
# ### **EJ031.**
#
# En una empresa que fabrica microcircuitos se ha comprobado que el 4% de estos son defectuosos. Un cliente compra un paquete de 500 microcircuitos procedentes de la fábrica. Determina:
#
# * Número esperado de microcircuitos no defectuosos.
# * Probabilidad de que se encuentre más del 5% de microcircuitos defectuosos.
# * Probabilidad de que el número de microcircuitos defectuosos esté entre 20 y 30 (sin incluir).

# %% [markdown]
# ### **EJ032.**
#
# Un paciente que padece una enfermedad rara de la sangre tiene probabilidad 0.4 de recuperarse. Si se sabe que 100 personas contrajeron esta enfermedad,
#
# * ¿cuál es la probabilidad de que sobrevivan menos de 30?
# * ¿Cuál es la probabilidad de que sobrevivan más de 40?

# %% [markdown]
# ### **EJ033.**
#
# Un proceso produce un 10% de artículos defectuosos. Si se seleccionan al azar 100 artículos del proceso,
# * ¿cuál es la probabilidad de que el número de defectuosos exceda los 13?
# * ¿y de que sea menor a 8?

# %% [markdown]
# ### **EJ034.**
#
# Los cambios en los procedimientos de los aeropuertos requieren una planificación considerable. Los índices de llegadas de los aviones son factores importantes que deben tomarse en cuenta. Suponga que los aviones pequeños llegan a cierto aeropuerto, de acuerdo con una variable aleatoria Poisson, con una frecuencia media de 6 por hora.
#
# * ¿Cuál es la probabilidad de que lleguen exactamente 4 aviones pequeños durante un periodo de una hora?
# * ¿Cuál es la probabilidad de que lleguen al menos 4 durante un periodo de una hora?
# * Si definimos un día laboral como de 12 horas, ¿cuál es la probabilidad de que al menos 75 aviones pequeños lleguen durante un día laboral?

# %% [markdown]
# ### **EJ035.**
#
# Se sabe que para cierto tipo de alambre de cobre ocurren, en promedio, 1.5 fallos por milímetro. ¿Cuál es la probabilidad de que no ocurran fallos en cierta parte de un alambre que tiene 5 milímetros de longitud?

# %% [markdown]
# ### **EJ036.**
#
# Un servicio de emergencias recibe por término medio 150 llamadas diarias. Determinar la probabilidad de que:
#
# * se reciban un día más de 165 llamadas,
# * se reciban menos de 130 llamadas,
# * entre 140 y 180 llamadas (ambos extremos incluidos).

# %% [markdown]
# ### **EJ037**
#
# Una empresa de fabricación de bolsas de plástico dispone de una máquina que realiza el proceso de sellado. Por ser máquinas que constantemente están trabajando tienen un desgaste continuo y, por ende, su tiempo de vida es una varaible exponencial con promedio de 10 meses. Si el último cambio de máquina se realizó hace 10 meses,
#
# * ¿cuál es la probabilidad de que deba cambiarse la máquina antes de los próximos 8 meses?
# * ¿cuál es la probabilidad de que deba cambiarse la máquina después de los próximos 10 meses?
# * ¿cuál es la probabilidad de que deba cambiarse la máquina después de 8 meses pero antes de 12 meses?

# %% [markdown]
# ### **EJ039**
#
# El tiempo que un producto está en un escaparate hasta su adquisición sigue una distribución exponencial con un tiempo promedio de 6 días.
#
# * Determina la probabilidad de que dure más de 6 días pero menos de 10.
# * Determina la probabilidad de que dure menos de 6 días.
# * Determina la probabildiad de que dure más de 10 días.

# %% [markdown]
# ### **EJ040**
#
# El tiempo que transcurre antes de que una persona sea atendida en una cafetería es una variable aleatoria que sigue una distribución exponencial con media de 4 minutos:
#
# * ¿Cuál es la probabilidad de que una persona sea atendida antes de que transcurran 3 minutos?
# * ¿Cuál es la probabilidad de que una persona sea atendida después de que transcurran 5 minutos?
