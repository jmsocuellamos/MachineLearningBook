# %% [markdown]
# # <font color="steelblue">190. Ejercicios variables aleatorias discretas</font>
#
# **Material desarrollado por los [equipos de trabajo de IA4LEGOS](https://ia4legos.umh.es/)**
#
#
# **Fecha última edición**: 10/05/2025
#
# **Licencia**: <small><a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br /></small>
#
# No olvides hacer una copia si deseas utilizarlo. Al usar estos contenidos, aceptas nuestros términos de uso y nuestra política de privacidad.

# %% [markdown]
# ## <font color='steelblue'>Introducción</font>
#
# **Descripción:** Colección de ejercicios sobre variables aleatorias discretas.

# %%
# Cargamos módulos de análisis numérico
import numpy as np          # importamos numpy como np
import pandas as pd         # importamos pandas como pd
import math                 # importamos módulo para cáculos matemáticos

# Cargamos módulos de análisis gráficos
from plotnine import *      # importamos módulo para gráficos con ggplot
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %config InlineBackend.figure_format = 'retina'

from scipy import stats

# %% [markdown]
# ### **Ej001.**
#
# El número de averías en coches de competición, en su primer año de uso, se distribuye según la siguiente información:

# %%
averias = [0, 1, 2, 3, 4]
probabilidad = [0.08, 0.24, 0.41, 0.20, 0.07]

# %% [markdown]
# * ¿Cuál es la probabilidad de que el número de averías se menor o igual a 3?
# * ¿Cuál es la probabilidad de que el número de averías se situé entre 1 y 3 (ambos valores icluidos)?
# * ¿Cuál es el valor esperado del número de averías?
# * ¿Cuál es la varianza del número de averías?

# %% [markdown]
# ### **Ej002.**
#
# El director de unos pequeños almacenes ha supervisado el número de quejas recibidas por día durante un period de tiempo muy largo. Las probabilidades correspondientes al número de quejas por día se muestran a continuación:

# %%
quejas = [0, 1, 2, 3, 4, 5]
probabilidad = [0.14, 0.39, 0.23, 0.25, 0.06, 0.03]

# %% [markdown]
# * ¿Cuál es la probabilidad de que el número de quejas sea menor o igual a 2?
# * ¿Cuál es la probabilidad de que el número de quejas sea superior a 2 y menor o igual a 5?
# * ¿Cuál es el valor esperado del número de quejas?
# * ¿Cuál es la desviación típica del número de quejas?

# %% [markdown]
# ### **EJ003.**
#
# Juan Compruebo, director de control de calidad en la compañia Kyoto Motor, está llevando a cabo su chequeo mensual de las transmisiones automáticas. En este proceso quita 10 transmisiones del panel de componentes y los chequea para comprobar defectos de fábrica. Históricamente, sólo el 2% de las transmisiones tienen tal defecto (y además los defectos ocurren independiente mente en diferentes transmisiones).
#
# * ¿Cuál es la probabilidad de que la muestra que ha elegido el director contenga más de 2 transmisiones con defectos de fábrica?
# * ¿Cuál es la probabilidad de que ninguna de las transmisiones seleccionadas tenga defectos de fábrica?

# %% [markdown]
# ### **EJ004.**
#
# Un estudio reciente de cómo los ilicitanos emplean su tiempo libre se llevó a cabo entre los trabajadores que estaban empleados al menos desde hacía 5 años. En dicho estudio se determinó que la probabilidad de que un empleado tenga 2 semanas de vacaciones es de 0.45, 1 semana de vacaciones de 0.10, y 3 o más semanas de vacaciones de 0.20. Supón que seleccionamos aleatoriamente 20 trabajadores. Contesta las siguientes cuestiones:
#
# * ¿Cuál es la probabilidad de que 8 de ellos tengan 2 semanas de vacaciones?
# * ¿Cuál es la probabilidad de que sólo un trabajador tenga 1 semana de vacaciones?
# * ¿Cuál es la probabilidad de que al menos 2 trabajadores tengan 3 o más semanas de vacaciones?

# %% [markdown]
# ### **EJ005.**
#
# Un cierto sistema electrónico contiene diez componentes. Supóngase que la probabilidad de que un componente individual falle es 0.2 y que los componentes fallan independientemente unos de otros. Dado que al menos uno de los componentes ha fallado, ¿cuál es la probabilidad de que fallen al menos dos de los componentes?

# %% [markdown]
# ### **EJ006.**
#
# En un proceso de fabricación de tornillos se sabe que el 2% son defectuosos. Los empaquetamos en cajas de 50 tornillos. Calcula la probabilidad de que en una caja tengamos:
#
# * Ningún tornillo defectuoso.
# * Exactamente un tornillo defectuoso.
# * Más de dos tornillos defectuosos.

# %% [markdown]
# ### **EJ007.**
#
# Antonio Rigor es el responsable de recursos humanos en Manufacturas Rigor. Lleva observando un tiempo, que uno de sus empleados se las ingenia para trabajar al menor ritmo posible. Además de las paradas habituales, este empleado para a descansar un promedio de 4.1 veces en una hora, y en cada una de esas paradas destina 3 minutos. Rigor ha decidido que, descontando las paradas generales y habituales, si la probabilidad de que este empleado descanse al menos 12 minutos durante una hora es mayor que 0.5, tirará a dicho empleado de la empresa. ¿Hará eso?

# %% [markdown]
# ### **EJ008.**
#
# En promedio, 5 palomas son atropelladas en los aledaños de la Plaza de Santa María a lo largo de una semana. Los de la Protectora de Animales han pedido fondos al Ayuntamiento para rescatar a las palomas y llevarlas a otro sitio menos peligroso. Los del Ayuntamiento han contestado que no darán los fondos a no ser que la probabilidad de que sean atropelladas más de 3 palomas en una semana supere el 0.7. ¿Darán los fondos?

# %% [markdown]
# ### **EJ009.**
#
# Microelectrónica Altabix ha desarrollado una nueva calculadora que realiza un montón de operaciones que no realiza ninguna otra calculadora en el mercado. El departamento de marketing están planeando mostrar esta calculadora a un grupo de clientes. Sin embargo, están preocupados por cierto problema de cálculos matemáticos inconsistentes que aparecen en un 4% de las nuevas calculadoras. Para la demostración, seleccionarán un grupo aleatorio de calculadoras, y obviamente están inquietos por si alguna de las seleccionadas da dichas inconsistencias. Si se cogen 50 calculadoras para la demostración, y usas una distribución de Poisson como aproximación a la binomial(Ayuda: $X\sim Bi(n,p)$ entonces $X \sim Po(n*p)$ siempre que n sea grande y p pequeña):
#
# * ¿Cuál es la probabilidad de que al menos 3 de estas calculadoras funcionen mal?
# * ¿Y la probabilidad de que ninguna de las calculadoras seleccionadas funcione mal?

# %% [markdown]
# ### **EJ010.**
#
# La Fábrica de la Moneda y Timbre (FMT) se encarga de la impresión del papel moneda, como bien sabes. La FMT tiene unos procesos de impresión muy controlados y sólo el 0.5% de los billetes se desechan para circulación, por contener erratas. Si tenemos ahora mismo una pila de 1000 billetes:
#
# * ¿Cuál es la probabilidad de que en la pila nnguno sea desechado?
# * ¿Cuál es la probabilidad de que a lo sumo 10 sean desechados?
# * ¿Cuál es la probabilidad de que a lo sumo 15 sean desechados?

# %% [markdown]
# ### **EJ011.**
#
# El número medio de automóviles que llega a una estación de suministro de gasolina es de 210 por hora. Si dicha estación puede atender a un máximo de 10 automóviles por minuto, determinar la probabilidad de que en un minuto dado lleguen a la estación de suministro más automóviles de los que puede atender.

# %% [markdown]
# ### **EJ012.**
#
# En la inspección de hojalata producida por un proceso electrolítico continuo, se identifican 0.2 imperfecciones en promedio por minuto. Determine las probabilidades de identificar:
#
# * una imperfección en 3 minutos,
# * al menos dos imperfecciones en 5 minutos,
# * más de una imperfección en 15 minutos.

# %% [markdown]
# ### **EJ013.**
#
# Una línea aérea vende 200 billetes para un vuelo de un avión que tiene únicamente 198 asientos porque, en promedio, el 1% de los clientes no aparecen en el momento de la salida del vuelo. Determínese:
#
# * La probabilidad de que todos los que acuden a la hora de salida de este vuelo tendrán su asiento.
# * La probabilidad de que asistan menos pasajeros que asientos disponibles.
# * La probabilidad de que al menos un pasajero se quede en tierra.

# %% [markdown]
# ### **EJ014.**
#
# Si el número de defectos de un rollo de tela fabricado con un cierto proceso tienen una distribución de Poisson con media 0.4. Si se inspecciona una muestra aleatoria de cinco rollos de tela.
#
# * ¿Cuál es la probabilidad de que el número total de defectos en los cinco rollos sea al menos 6?
# * ¿Cuál es la probabilidad de que el número total de defectos en los cinco rollos sea entre 4 y 7 (ambos incluídos)?

# %% [markdown]
# ### **EJ015.**
#
# Estamos revisando en una empresa el comportamiento de las bajas laborales. En base al histórico, se tiene que cada día aproximadamente el 3% de los trabajadores faltan al trabajo alegando una baja laboral. Si el número de trabajadores de la empresa es de 150, queremos saber qué porcentaje de días vamos a tener al menos 3 trabajadores de baja.

# %% [markdown]
# ### **EJ016.**
#
# Una empresa de fabricación produce piezas, de las cuales el 97% están dentro de las especiﬁcaciones y el 3% son defectuosas (fuera de las especiﬁcaciones). Aparentemente no hay ningún patrón en la producción de piezas defectuosas. La cadena de producción empaqueta las piezas en cajas de 20 piezas cada una, y produce 1000 cajas al día. Al gerente de la empresa le gustaría estimar el número de cajas con al menos dos piezas defectuosas, de entre todas las que se producen al día durante un día cualquiera.

# %% [markdown]
# ### **EJ017.**
#
# Una vendedora de coches ha hecho un análisis estadístico de su historial de ventas anterior y ha determinado que cada día tiene un 10% de probabilidad de vender un coche de lujo, independientemente de cuántos haya vendido los días anteriores. Contando desde hoy, ¿cuántos días tardará en vender el primer coche de lujo?

# %% [markdown]
# ### **EJ018.**
#
# En el estudio de cierto organismo acuático, se toman un gran número de muestras de un lago y se cuenta el número de dichos organismos que aparecen en cada muestra; en promedio es 2. Se quiere saber cuál es la probabilidad de encontrar dicho organismo en una próxima muestra.

# %% [markdown]
# ### **EJ019.**
#
# Una empresa de asesoramiento está realizando el análisis del funcionamiento de una panadería y ha estimado que el número medio de barras de pan que se venden en un periodo de media hora es de 12. La empresa está interesada en saber:
# - ¿cuál es la capacidad de venta en cada franja de diez minutos (pues es prácticamente el tiempo de horneado)?
# - ¿cuál es la probabilidad de que el número de barras que se venden en diez minutos sea exactamente de tres?

# %% [markdown]
# ### **EJ020.**
#
# En un estudio sobre la efectividad de un insecticida sobre cierto tipo de insecto, se fumiga una gran región. Posteriormente se crea una cuadrícula sobre el terreno, se selecciona de forma aleatoria un conjunto de ellas, y se cuenta el número de insectos vivos dentro de cada una. ¿Cuál es la probabilidad de que no encontremos ningún insecto vivo en una próxima cuadrícula, si se sabe que la media de insectos vivos en las cuadrículas analizadas es de 0.5?

# %% [markdown]
# ### **EJ021.**
#
# Un grupo de investigadores observó la ocurrencia de hemangioma capilar retiniano (RCH) en pacientes con la enfermedad de von Hippel-Lindau (VHL). RCH es un tumor vascular benigno de la retina. Usando una revisión retrospectiva de series de casos consecutivos, los investigadores encontraron que el número de medio de tumores RCH por ojo para pacientes con VHL era de 4. ¿Cuál es la probabilidad de que se detecten más de cuatro tumores por ojo?

# %% [markdown]
# ### **EJ022.**
#
# Juan Compruebo, director de control de calidad en la compañía Kyoto Motor, está llevando a cabo su chequeo mensual de las transmisiones automáticas. En este proceso quita 10 transmisiones del panel de componentes y los chequea para comprobar defectos de fábrica. Históricamente, sólo el 2% de las transmisiones tienen tal defecto (y además los defectos ocurren independiente mente en diferentes transmisiones).
#
# * ¿Cuál es la probabilidad de que la muestra que ha elegido el director contenga más de 2 transmisiones con defectos de fábrica?
# * ¿Cuál es la probabilidad de que ninguna de las transmisiones seleccionadas tenga defectos de fábrica?

# %% [markdown]
# ### **EJ023.**
#
# De la información obtenida en los últimos tres años se conoce que la probabilidad que un juzgado tome medidas cautelares en casos de violencia de género es del 70%. Ahora mismo el juzgado tiene 20 casos pendientes de posible violencia de género. Estamos interesados en conocer:
#
# * ¿Cuál es la probabilidad de que tomen medidas cautelares en 8 de los nuevos 20 casos?
# * ¿Cuál es la probabilidad de que al menos se tomen medidas cautelares en 10 casos?
# * ¿Cuál es la probabilidad de que se tomen medidas cautelares en menos de 12 (incluido) de los nuevos casos?
# * ¿cuál es la probabilidad de que se tomen medidas cautelares entre 10 y 15 casos (ambos inclusive)?

# %% [markdown]
# ### **EJ024.**
#
# El registro histórico de los controles de consumo de drogas en una pequeña ciudad muestran que el 45% de los sujetos había consumido algún tipo de droga. Si el próximo fin de semana se pasa el test a 60 sujetos:
#
# * ¿Cuál es el valor esperado de sujetos que den positivo en el test?
# * ¿Cuál es la probabilidad de que más del 50% de los sujetos den positivo?
# * ¿Y la del 75% de los sujetos?
# * ¿Cuál es la probabilidad de que como máximo 15 sujetos den positivo en el test?

# %% [markdown]
# ### **EJ025.**
#
# Durante el proceso de comprobación de los permisos en un mercado ambulante de la ciudad se detecta que el 10% de ellos no cumplen con los criterios necesarios. Si en este fin de semana se han colocado 65 puesto en el mercado:
#
# * ¿Cuál es la probabilidad de que todos ellos cumplan con los permisos?
# * ¿y de qué lo cumplan al menos el 80% de ellos?

# %% [markdown]
# ### **EJ026.**
#
# Los sábados por la mañana, los clientes entran en una pequeña tienda de un centro comercial a una tasa esperada de 0.5 clientes por minuto.  Se está interesado en estudiar lo que ocurriría en un periodo de 10 minutos. En dicha situación estamos interesados en las siguientes cuestiones:
#
# * ¿Probabilidad de qué entren 3 clientes en los próximos 10 minutos?
# * ¿Probabilidad de que como mucho entre 1 cliente en los próximos 10 minutos?
# * ¿Probabilidad  de que al menos entren 2 clientes en los próximos 10 minutos?
# * ¿Probabilidad de qué entren entre 1 y 2 clientes (ambos incluidos) en los próximos 10 minutos?

# %% [markdown]
# ### **EJ027.**
#
# El número medio de accidentes graves registrados en un punto negro de la ciudad es de 2 accidentes cada 2 meses. Estamos interesados en conocer:
#
# * ¿Cuál es la probabilidad de que haya más de 2 accidentes en 2 meses?
# * ¿Cuál es la probabilidad de que haya entre 2 y 5 accidentes (ambos inclusive) en 2 meses?
# * ¿Cuál es la probabilidad de que haya más de 2 accidentes en un mes?
# * ¿Cuál es la probabilidad de que haya más de 20 accidentes en los próximos seis meses?

# %% [markdown]
# ### **EJ028**.
#
# El recuento de glóbulos blancos de un individuo sano puede presentar un promedio en valor mínimo de hasta 6000 por litro cúbico de sangre. Para detectar una deficiencia de glóbulos blancos se determina su número en una gota de sangre de 0.001 milímetros cúbicos.
#
# * ¿Cuántos glóbulos blancos cabe esperar en un individuo sano?
# * ¿Cuánto de raro sería encontrar un máximo de 2 glóbulos blancos?

# %% [markdown]
# ### **EJ029**.
#
# La probabilidad de una alineación óptica con éxito en el montaje de un producto óptico, según especificaciones para su almacenamiento, es de 0.8. Suponga que los intentos de montaje son independientes.
#
# * ¿Cuál es la probabilidad de que la alineación con éxito se produzca por primera vez en el quinto ensayo?
# * ¿Cuál es la probabilidad de que la primera alineación con éxito requiera como mínimo cuatro
# intentos?
# * ¿Cuál es la probabilidad de que la primera alineación con éxito requiera a lo menos cuatro y a lo
# más 6 intentos?
# * ¿Cuántos intentos se espera realizar para lograr el primer éxito?
# * Calcular la desviación típica del número de intentos hasta lograr éxito en la alineación.

# %% [markdown]
# ### **EJ030**.
#
# Un científico inocula varias ratas, una a la vez, con un germen de cierta enfermedad hasta lograr una que la
# haya contraído. Si la probabilidad de contraer la enfermedad es 1/6,
#
# * ¿Cuál es la probabilidad de que se requieran 8 inoculaciones hasta encontrar una rata que haya contraído la enfermedad?
# * ¿Cuál es la probabilidad de que por primera vez a lo más en la cuarta inoculación se encuentre una rata que haya contraído la enfermedad?
# * ¿Cuál es la probabilidad de que se requiera como mínimo cinco inoculaciones para encontrar la primera rata que haya contraído la enfermedad?
# * ¿Cuál es la probabilidad de que se requiera a lo menos cuatro y a lo más 6 inoculaciones para encontrar la primera rata que haya contraído la enfermedad?
# * ¿Cuántos intentos se espera realizar para encontrar la primera rata que haya contraído la enfermedad?
# * Calcular la desviación estándar del número de intentos hasta encontrar la primera rata que haya contraído la enfermedad?

# %% [markdown]
# ### **EJ031**
#
# Supongamos que cada una de las llamadas a una popular emisora de radio tiene una probabilidad de 0,02 de obtener conexión (es decir, de no obtener una señal de ocupado). Suponga que las llamadas son independientes.
# * ¿Cuál es la probabilidad de que la primera llamada que se conecta la décima que se realiza?
# * ¿Cuál es la probabilidad de que se requiera más de cinco llamadas para que usted pueda
# conectarse?
# * ¿Cuál es el número medio de llamadas necesarias para conectarse?

# %% [markdown]
# ### **EJ032**
#
# En su viaje de cada mañana al trabajo, un particular semáforo está de color verde el 20% de las veces en usted se acerca en su vehículo a él. Supongamos que cada mañana representa un evento independiente.
# * ¿Cuál es la probabilidad de que hayan pasado más de cinco mañanas hasta que usted se encuentre con el semáforo en verde?
# * ¿Cuál es la probabilidad de que hayan pasado veinte mañanas hasta que usted se encuentre con el semáforo en verde?
# * ¿Cuál es la probabilidad de que hayan pasado más de veinte mañanas hasta que usted se encuentre con el semáforo en verde?
# * ¿Cuál es la probabilidad de que la primera mañana en que la luz esté en verde sea la cuarta mañana en que usted se aproxima al semáforo?

# %% [markdown]
# ### **EJ033**
#
# Una empresa comercial tiene un equipo computacional que utiliza para el comercio al exterior de su región. La probabilidad de que el equipo falle en un día es de 0.005, y
# cuando falla el equipo es reparado inmediatamente por la noche. Cada día es un evento independiente.
#
# * ¿Cuál es la probabilidad de que el equipo falle el primer día en que es puesto en funcionamiento?
# * ¿Cuál es la probabilidad de que el equipo falle después del tercer día de funcionamiento? ¿Se puede estar tranquilo en la empresa al observar este resultado?
# * ¿Cuál es el número medio de días de buen funcionamiento hasta que el equipo falle?

# %% [markdown]
# ### **EJ034**

# %% [markdown]
# ### **EJ035**
#
# En el control de equipaje de un aeropuerto se sabe que el 3% de las personas revisadas tienen objetos cuestionables en su equipaje.
# * ¿Cuál es la probabilidad de que una cadena de 15 personas pase el control con éxito antes de que pase un individuo con un objeto cuestionable?
# * ¿Cuál es el número esperado de individuos que pasan el control en una fila antes de que un individuo detenga el proceso?

# %% [markdown]
# ### **EJ036**
#
# Sea $X$ una variable aleatoria discreta cuya función de masa de probabilidad viene dada por:
#
# | x | P(X=x) |
# |-------|:-------:|
# |0|0.1|
# |1|0.2|
# |2|0.1|
# |3|0.4|
# |4|0.1|
# |5|0.1|
#
# Calcular:
#
# * Gráfico de función de masa de probabilidad y función de distribución.
# * Probabildiad de que el valor de X sea al menos igual a 4.
# * Probabilidad de que el valor de X sea como máximo igual a 3.
# * Probabilidad de que el valor de X se encuentre entre 3 y 5 (
# ambos inclusive).

# %% [markdown]
# ### **EJ037**
#
# Una variable aleatoria $X$ puede tomar los valores 30,40,50 y 60 con probabilidades 0.4, 0.2, 0.1 y 0.3. Represente la función de masa de probabilidad y la función de distribución, y determine las siguientes probabilidades.
#
# * $P( X ≤ 25)$
# * $P(X ≥ 60)$
# * $P(X < 40)$
# * $P(X > 40)$
# * $P(30 ≤ X ≤ 60)$
# * $P(30 ≤ X < 60)$
# * $P(30 < X ≤ 60)$
# * $P(30 < X < 60)$
# * Obtén la esperanza y varianza de X

# %% [markdown]
# ### **EJ038**
#
# Con la variable aleatoria $X$, cuya función de probabildiad viene en la tabla siguiente:
#
# | x | P(X=x) |
# |-------|:-------:|
# |10|0.10|
# |12|0.30|
# |14|0.25|
# |16|0.1|
# |18|0.1|
# |20|0.15|
#
# * Determina la esperanza y varainza de $X$
# * Determina las siguientes probabilidades:
#   * $P( X ≤ 33)$
#   * $P(X \leq 14.5)$
#   * $P(X \leq 3)$
#   * $P(10.5 ≤ X ≤ 17.5)$

# %% [markdown]
# ### **EJ039**
#
# Un trabajador recibirá un premio de 3000, 2000 o 1000 euros, según el tiempo que tarde en realizar un trabajo en menos de 10 horas, entre 10 y 15 horas y más de 15 horas,respectivamente.
#
# La probabilidad de realizar el trabajo en cada uno de estos casos es de 0.1, 0.4 y 0.5.
#
# * Determine la esperanza y la función de probabilidad de la variable aleatoria X=premio recibido.
# * Defina una nueva variable aleatoria,Y, con valor 1 si tarda menos de 10 horas y valor 0, en caso contrario. Obtén la distribución de probabilidad, esperanza y varianza

# %% [markdown]
# ### **EJ040**
#
# Las líneas de teléfono de un sistema de reserva de vuelos están ocupadas el 40% del tiempo. Supongamos que los eventos en que las líneas estén ocupadas en las sucesivas llamadas son independientes. Si se realizan 10 llamadas a la compañía aérea:
# * ¿Cuál es la probabilidad de que en exactamente tres llamadas las líneas estén ocupadas?
# * ¿Cuál es la probabilidad de que al realizar una llamada las líneas no están ocupadas?
# * ¿Cuál es el número esperado de llamadas en las que las líneas están ocupadas?¿y la desviación típica?

# %% [markdown]
# ### **EJ041**

# %% [markdown]
# ### **EJ042**
#
# Un proceso de fabricación cuenta con 100 pedidos de clientes. Cada orden requiere un componente que se compra a un proveedor y un 2% de éstos ha resultado defectuoso. Se puede suponer que los componentes son independientes.
# * Si el fabricante dispone de un stock de 100 componentes, ¿cuál es la probabilidad de que las 100 órdenes puedan llenarse sin necesitar comprar nuevas componentes?
# * Si el fabricante cuenta con 102 componentes, ¿cuál es la probabilidad de que las 100 órdenes pueden llenarse sin necesitar comprar nuevas componentes?
# * Si el fabricante cuenta con 105 componentes, ¿cuál es la probabilidad de que las 100 órdenes pueden llenarse sin necesitar comprar nuevas componentes?

# %% [markdown]
# ### **EJ043**
#
# Cada hora se seleccionan muestras de 20 partes de un proceso de troquelado de metal (el proceso consiste en cortar con precisión de medidas con un troquel). Normalmente, el 1% de las piezas requieren de revisión. Sea X el número de piezas en la muestra de 20 que requieren revisión. El problema del proceso es que se sospecha X supera su media en más de tres desviaciones típicas.
#
# * Si el porcentaje de piezas que requieren rehacerse mantiene en el 1%, ¿cuál es la probabilidad de que X supere su media de más de tres desviaciones típicas?
# * Si el porcentaje que debe rehacerse aumenta al 4%, ¿cuál es la probabilidad de que X sea superior a 1?
# * Si el porcentaje que debe rehacerse aumenta al 4%, ¿cuál es la probabilidad de que X sea superior a 1 en al menos uno de los próximos cinco horas de muestras?

# %% [markdown]
# ### **EJ044**

# %% [markdown]
# ### **EJ045**
#
# Un estudio de inventario en un almacén determina que, en promedio, la demanda de un artículo particular se hace 5 veces al día. ¿Cuál es la probabilidad de que en un día
# determinado este artículo sea solicitado
# * ¿Cuál es la probabilidad de que en un día determinado este artículo sea solicitado más de 5 veces al día?
# * ¿Cuál es la probabilidad de que en un día determinado este artículo sea solicitado no en todos los días?
